# %%
# from google.colab import drive
# drive.mount("/content/drive")

# !cp '/content/drive/MyDrive/aiactive/augmented_data.zip' 'augmented_data.zip'
# !cp '/content/drive/MyDrive/aiactive/test_data.zip' 'test_data.zip'

# !unzip 'augmented_data.zip'
# !unzip 'test_data.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: augmented_data/crossover/augmented_549.jpg
#   inflating: augmented_data/crossover/augmented_563.jpg
#   inflating: augmented_data/crossover/augmented_520.jpg
#   inflating: augmented_data/crossover/crossover-back (327).jpg
#   inflating: augmented_data/crossover/augmented_396.jpg
#   inflating: augmented_data/crossover/crossover-front (446).jpg
#   inflating: augmented_data/crossover/augmented_922.jpg
#   inflating: augmented_data/crossover/crossover-front (30).jpg
#   inflating: augmented_data/crossover/augmented_149.jpg
#   inflating: augmented_data/crossover/augmented_350.jpg
#   inflating: augmented_data/crossover/augmented_695.jpg
#   inflating: augmented_data/crossover/augmented_797.jpg
#   inflating: augmented_data/crossover/augmented_399.jpg
#   inflating: augmented_data/crossover/augmented_792.jpg
#   inflating: augmented_data/crossover/crossover-front (388).jpg
#   inflating: augmented_data/crossover/augmented_420.jpg
#   inflating: augmented_data/crossover/augmented_401.jpg
#   inflating: augmented_data/crossover/crossover-front (67).jpg
#   inflating: augmented_data/crossover/augmented_702.jpg
#   inflating: augmented_data/crossover/augmented_252.jpg
#   inflating: augmented_data/crossover/augmented_887.jpg
#   inflating: augmented_data/crossover/augmented_929.jpg
#   inflating: augmented_data/crossover/augmented_805.jpg
#   inflating: augmented_data/crossover/augmented_244.jpg
#   inflating: augmented_data/crossover/crossover-back (251).jpg
#   inflating: augmented_data/crossover/augmented_164.jpg
#   inflating: augmented_data/crossover/crossover-back (259).jpg
#   inflating: augmented_data/crossover/augmented_447.jpg
#   inflating: augmented_data/crossover/augmented_346.jpg
#   inflating: augmented_data/crossover/augmented_26.jpg
#   inflating: augmented_data/crossover/augmented_597.jpg
#   inflating: augmented_data/crossover/crossover-front (218).jpg
#   inflating: augmented_data/crossover/crossover-back (248).jpg
#   inflating: augmented_data/crossover/augmented_944.jpg
#   inflating: augmented_data/crossover/augmented_781.jpg
#   inflating: augmented_data/crossover/augmented_171.jpg
#   inflating: augmented_data/crossover/augmented_374.jpg
#   inflating: augmented_data/crossover/augmented_409.jpg
#   inflating: augmented_data/crossover/augmented_571.jpg
#   inflating: augmented_data/crossover/augmented_923.jpg
#   inflating: augmented_data/crossover/augmented_936.jpg
#   inflating: augmented_data/crossover/augmented_199.jpg
#   inflating: augmented_data/crossover/augmented_305.jpg
#   inflating: augmented_data/crossover/augmented_825.jpg
#   inflating: augmented_data/crossover/augmented_569.jpg
#   inflating: augmented_data/crossover/crossover-front (259).jpg
#   inflating: augmented_data/crossover/augmented_329.jpg
#   inflating: augmented_data/crossover/crossover-front (329).jpg
#   inflating: augmented_data/crossover/augmented_13.jpg
#   inflating: augmented_data/crossover/crossover-front (29).jpg
#   inflating: augmented_data/crossover/crossover-front (162).jpg
#   inflating: augmented_data/crossover/crossover-front (293).jpg
#   inflating: augmented_data/crossover/augmented_752.jpg
#   inflating: augmented_data/crossover/augmented_955.jpg
#   inflating: augmented_data/crossover/augmented_497.jpg
#   inflating: augmented_data/crossover/crossover-back (349).jpg
#   inflating: augmented_data/crossover/augmented_782.jpg
#   inflating: augmented_data/crossover/augmented_217.jpg
#   inflating: augmented_data/crossover/augmented_475.jpg
#   inflating: augmented_data/crossover/crossover-front (279).jpg
#   inflating: augmented_data/crossover/augmented_637.jpg
#   inflating: augmented_data/crossover/augmented_864.jpg
#   inflating: augmented_data/crossover/augmented_620.jpg
#   inflating: augmented_data/crossover/augmented_84.jpg
#   inflating: augmented_data/crossover/augmented_278.jpg
#   inflating: augmented_data/crossover/augmented_576.jpg
#   inflating: augmented_data/crossover/crossover-front (270).jpg
#   inflating: augmented_data/crossover/augmented_479.jpg
#   inflating: augmented_data/crossover/augmented_835.jpg
#   inflating: augmented_data/crossover/crossover-front (423).jpg
#   inflating: augmented_data/crossover/crossover-front (195).jpg
#   inflating: augmented_data/crossover/crossover-front (236).jpg
#   inflating: augmented_data/crossover/crossover-front (364).jpg
#   inflating: augmented_data/crossover/crossover-back (129).jpg
#   inflating: augmented_data/crossover/augmented_360.jpg
#   inflating: augmented_data/crossover/augmented_190.jpg
#   inflating: augmented_data/crossover/augmented_904.jpg
#   inflating: augmented_data/crossover/augmented_612.jpg
#   inflating: augmented_data/crossover/augmented_916.jpg
#   inflating: augmented_data/crossover/augmented_560.jpg
#   inflating: augmented_data/crossover/crossover-back (328).jpg
#   inflating: augmented_data/crossover/augmented_647.jpg
#   inflating: augmented_data/crossover/augmented_846.jpg
#   inflating: augmented_data/crossover/crossover-front (54).jpg
#   inflating: augmented_data/crossover/augmented_218.jpg
#   inflating: augmented_data/crossover/augmented_311.jpg
#   inflating: augmented_data/crossover/augmented_227.jpg
#   inflating: augmented_data/crossover/augmented_381.jpg
#   inflating: augmented_data/crossover/crossover-front (66).jpg
#   inflating: augmented_data/crossover/crossover-back (271).jpg
#   inflating: augmented_data/crossover/augmented_225.jpg
#   inflating: augmented_data/crossover/crossover-front (194).jpg
#   inflating: augmented_data/crossover/augmented_796.jpg
#   inflating: augmented_data/crossover/augmented_144.jpg
#   inflating: augmented_data/crossover/crossover-front (183).jpg
#   inflating: augmented_data/crossover/crossover-back (311).jpg
#   inflating: augmented_data/crossover/crossover-front (103).jpg
#   inflating: augmented_data/crossover/augmented_284.jpg
#   inflating: augmented_data/crossover/augmented_97.jpg
#   inflating: augmented_data/crossover/augmented_31.jpg
#   inflating: augmented_data/crossover/augmented_838.jpg
#   inflating: augmented_data/crossover/crossover-front (410).jpg
#   inflating: augmented_data/crossover/crossover-front (434).jpg
#   inflating: augmented_data/crossover/augmented_465.jpg
#   inflating: augmented_data/crossover/augmented_3.jpg
#   inflating: augmented_data/crossover/augmented_623.jpg
#   inflating: augmented_data/crossover/crossover-back (164).jpg
#   inflating: augmented_data/crossover/crossover-back (199).jpg
#   inflating: augmented_data/crossover/crossover-back (162).jpg
#   inflating: augmented_data/crossover/augmented_333.jpg
#   inflating: augmented_data/crossover/crossover-front (379).jpg
#   inflating: augmented_data/crossover/crossover-back (61).jpg
#   inflating: augmented_data/crossover/augmented_644.jpg
#   inflating: augmented_data/crossover/augmented_263.jpg
#   inflating: augmented_data/crossover/crossover-front (173).jpg
#   inflating: augmented_data/crossover/augmented_471.jpg
#   inflating: augmented_data/crossover/augmented_598.jpg
#   inflating: augmented_data/crossover/crossover-back (138).jpg
#   inflating: augmented_data/crossover/augmented_213.jpg
#   inflating: augmented_data/crossover/augmented_243.jpg
#   inflating: augmented_data/crossover/augmented_816.jpg
#   inflating: augmented_data/crossover/crossover-front (449).jpg
#   inflating: augmented_data/crossover/crossover-back (1).jpg
#   inflating: augmented_data/crossover/crossover-front (273).jpg
#   inflating: augmented_data/crossover/crossover-back (127).jpg
#   inflating: augmented_data/crossover/crossover-front (402).jpg
#   inflating: augmented_data/crossover/augmented_924.jpg
#   inflating: augmented_data/crossover/augmented_69.jpg
#   inflating: augmented_data/crossover/crossover-front (184).jpg
#   inflating: augmented_data/crossover/crossover-front (5).jpg
#   inflating: augmented_data/crossover/augmented_249.jpg
#   inflating: augmented_data/crossover/augmented_127.jpg
#   inflating: augmented_data/crossover/augmented_368.jpg
#   inflating: augmented_data/crossover/augmented_806.jpg
#   inflating: augmented_data/crossover/augmented_120.jpg
#   inflating: augmented_data/crossover/augmented_688.jpg
#   inflating: augmented_data/crossover/crossover-back (363).jpg
#   inflating: augmented_data/crossover/augmented_236.jpg
#   inflating: augmented_data/crossover/augmented_160.jpg
#   inflating: augmented_data/crossover/augmented_468.jpg
#   inflating: augmented_data/crossover/augmented_186.jpg
#   inflating: augmented_data/crossover/augmented_82.jpg
#   inflating: augmented_data/crossover/augmented_899.jpg
#   inflating: augmented_data/crossover/augmented_956.jpg
#   inflating: augmented_data/crossover/crossover-front (391).jpg
#   inflating: augmented_data/crossover/crossover-back (341).jpg
#   inflating: augmented_data/crossover/crossover-front (28).jpg
#   inflating: augmented_data/crossover/augmented_567.jpg
#   inflating: augmented_data/crossover/augmented_324.jpg
#   inflating: augmented_data/crossover/augmented_803.jpg
# ...
#   inflating: test/sedan/sedan-back (1573).jpg
#   inflating: test/sedan/sedan-back (1574).jpg
#   inflating: test/sedan/sedan-back (1575).jpg
#   inflating: test/sedan/sedan-back (1576).jpg
#   inflating: test/sedan/sedan-back (1596).jpg
#   inflating: test/sedan/sedan-back (1597).jpg
#   inflating: test/sedan/sedan-back (1598).jpg
#   inflating: test/sedan/sedan-back (1599).jpg
#   inflating: test/sedan/sedan-back (1611).jpg
#   inflating: test/sedan/sedan-back (1612).jpg
#   inflating: test/sedan/sedan-back (1613).jpg
#   inflating: test/sedan/sedan-back (1619).jpg
#   inflating: test/sedan/sedan-back (1620).jpg
#   inflating: test/sedan/sedan-back (1635).jpg
#   inflating: test/sedan/sedan-back (1636).jpg
#   inflating: test/sedan/sedan-back (1637).jpg
#   inflating: test/sedan/sedan-back (1643).jpg
#   inflating: test/sedan/sedan-back (1655).jpg
#   inflating: test/sedan/sedan-back (1656).jpg
#   inflating: test/sedan/sedan-back (1657).jpg
#   inflating: test/sedan/sedan-back (1658).jpg
#   inflating: test/sedan/sedan-back (1659).jpg
#   inflating: test/sedan/sedan-back (1679).jpg
#   inflating: test/sedan/sedan-back (1680).jpg
#   inflating: test/sedan/sedan-back (1681).jpg
#   inflating: test/sedan/sedan-back (1682).jpg
#   inflating: test/sedan/sedan-back (1694).jpg
#   inflating: test/sedan/sedan-back (1695).jpg
#   inflating: test/sedan/sedan-back (1696).jpg
#   inflating: test/sedan/sedan-back (1697).jpg
#   inflating: test/sedan/sedan-back (1703).jpg
#   inflating: test/sedan/sedan-back (171).jpg
#   inflating: test/sedan/sedan-back (1718).jpg
#   inflating: test/sedan/sedan-back (1719).jpg
#   inflating: test/sedan/sedan-back (1720).jpg
#   inflating: test/sedan/sedan-back (1721).jpg
#   inflating: test/sedan/sedan-back (1733).jpg
#   inflating: test/sedan/sedan-back (1739).jpg
#   inflating: test/sedan/sedan-back (1740).jpg
#   inflating: test/sedan/sedan-back (1741).jpg
#   inflating: test/sedan/sedan-back (1742).jpg
#   inflating: test/sedan/sedan-back (179).jpg
#   inflating: test/sedan/sedan-back (180).jpg
#   inflating: test/sedan/sedan-back (181).jpg
#   inflating: test/sedan/sedan-back (195).jpg
#   inflating: test/sedan/sedan-back (203).jpg
#   inflating: test/sedan/sedan-back (204).jpg
#   inflating: test/sedan/sedan-back (205).jpg
#   inflating: test/sedan/sedan-back (206).jpg
#   inflating: test/sedan/sedan-back (230).jpg
#   inflating: test/sedan/sedan-back (231).jpg
#   inflating: test/sedan/sedan-back (239).jpg
#   inflating: test/sedan/sedan-back (240).jpg
#   inflating: test/sedan/sedan-back (254).jpg
#   inflating: test/sedan/sedan-back (255).jpg
#   inflating: test/sedan/sedan-back (263).jpg
#   inflating: test/sedan/sedan-back (264).jpg
#   inflating: test/sedan/sedan-back (265).jpg
#   inflating: test/sedan/sedan-back (289).jpg
#   inflating: test/sedan/sedan-back (290).jpg
#   inflating: test/sedan/sedan-back (291).jpg
#   inflating: test/sedan/sedan-back (299).jpg
#   inflating: test/sedan/sedan-back (313).jpg
#   inflating: test/sedan/sedan-back (314).jpg
#   inflating: test/sedan/sedan-back (315).jpg
#   inflating: test/sedan/sedan-back (323).jpg
#   inflating: test/sedan/sedan-back (324).jpg
#   inflating: test/sedan/sedan-back (348).jpg
#   inflating: test/sedan/sedan-back (349).jpg
#   inflating: test/sedan/sedan-back (350).jpg
#   inflating: test/sedan/sedan-back (351).jpg
#   inflating: test/sedan/sedan-back (372).jpg
#   inflating: test/sedan/sedan-back (373).jpg
#   inflating: test/sedan/sedan-back (374).jpg
#   inflating: test/sedan/sedan-back (375).jpg
#   inflating: test/sedan/sedan-back (383).jpg
#   inflating: test/sedan/sedan-back (407).jpg
#   inflating: test/sedan/sedan-back (408).jpg
#   inflating: test/sedan/sedan-back (409).jpg
#   inflating: test/sedan/sedan-back (410).jpg
#   inflating: test/sedan/sedan-back (431).jpg
#   inflating: test/sedan/sedan-back (432).jpg
#   inflating: test/sedan/sedan-back (433).jpg
#   inflating: test/sedan/sedan-back (434).jpg
#   inflating: test/sedan/sedan-back (435).jpg
#   inflating: test/sedan/sedan-back (459).jpg
#   inflating: test/sedan/sedan-back (467).jpg
#   inflating: test/sedan/sedan-back (468).jpg
#   inflating: test/sedan/sedan-back (469).jpg
#   inflating: test/sedan/sedan-back (483).jpg
#   inflating: test/sedan/sedan-back (491).jpg
#   inflating: test/sedan/sedan-back (492).jpg
#   inflating: test/sedan/sedan-back (493).jpg
#   inflating: test/sedan/sedan-back (494).jpg
#   inflating: test/sedan/sedan-back (518).jpg
#   inflating: test/sedan/sedan-back (519).jpg
#   inflating: test/sedan/sedan-back (527).jpg
#   inflating: test/sedan/sedan-back (528).jpg
#   inflating: test/sedan/sedan-back (542).jpg
#   inflating: test/sedan/sedan-back (543).jpg
#   inflating: test/sedan/sedan-back (551).jpg
#   inflating: test/sedan/sedan-back (552).jpg
#   inflating: test/sedan/sedan-back (553).jpg
#   inflating: test/sedan/sedan-back (577).jpg
#   inflating: test/sedan/sedan-back (578).jpg
#   inflating: test/sedan/sedan-back (579).jpg
#   inflating: test/sedan/sedan-back (587).jpg
#   inflating: test/sedan/sedan-back (60).jpg
#   inflating: test/sedan/sedan-back (601).jpg
#   inflating: test/sedan/sedan-back (602).jpg
#   inflating: test/sedan/sedan-back (603).jpg
#   inflating: test/sedan/sedan-back (61).jpg
#   inflating: test/sedan/sedan-back (611).jpg
#   inflating: test/sedan/sedan-back (612).jpg
#   inflating: test/sedan/sedan-back (62).jpg
#   inflating: test/sedan/sedan-back (63).jpg
#   inflating: test/sedan/sedan-back (636).jpg
#   inflating: test/sedan/sedan-back (637).jpg
#   inflating: test/sedan/sedan-back (638).jpg
#   inflating: test/sedan/sedan-back (639).jpg
#   inflating: test/sedan/sedan-back (660).jpg
#   inflating: test/sedan/sedan-back (661).jpg
#   inflating: test/sedan/sedan-back (662).jpg
#   inflating: test/sedan/sedan-back (663).jpg
#   inflating: test/sedan/sedan-back (671).jpg
#   inflating: test/sedan/sedan-back (695).jpg
#   inflating: test/sedan/sedan-back (696).jpg
#   inflating: test/sedan/sedan-back (697).jpg
#   inflating: test/sedan/sedan-back (698).jpg
#   inflating: test/sedan/sedan-back (719).jpg
#   inflating: test/sedan/sedan-back (720).jpg
#   inflating: test/sedan/sedan-back (721).jpg
#   inflating: test/sedan/sedan-back (722).jpg
#   inflating: test/sedan/sedan-back (723).jpg
#   inflating: test/sedan/sedan-back (747).jpg
#   inflating: test/sedan/sedan-back (755).jpg
#   inflating: test/sedan/sedan-back (756).jpg
#   inflating: test/sedan/sedan-back (757).jpg
#   inflating: test/sedan/sedan-back (771).jpg
#   inflating: test/sedan/sedan-back (779).jpg
#   inflating: test/sedan/sedan-back (780).jpg
#   inflating: test/sedan/sedan-back (781).jpg
#   inflating: test/sedan/sedan-back (782).jpg
#   inflating: test/sedan/sedan-back (806).jpg
#   inflating: test/sedan/sedan-back (807).jpg
#   inflating: test/sedan/sedan-back (815).jpg
#   inflating: test/sedan/sedan-back (816).jpg
#   inflating: test/sedan/sedan-back (830).jpg
#   inflating: test/sedan/sedan-back (831).jpg
#   inflating: test/sedan/sedan-back (839).jpg
#   inflating: test/sedan/sedan-back (84).jpg
#   inflating: test/sedan/sedan-back (840).jpg
#   inflating: test/sedan/sedan-back (841).jpg
#   inflating: test/sedan/sedan-back (85).jpg
#   inflating: test/sedan/sedan-back (86).jpg
#   inflating: test/sedan/sedan-back (865).jpg
#   inflating: test/sedan/sedan-back (866).jpg
#   inflating: test/sedan/sedan-back (867).jpg
#   inflating: test/sedan/sedan-back (87).jpg
#   inflating: test/sedan/sedan-back (875).jpg
#   inflating: test/sedan/sedan-back (889).jpg
#   inflating: test/sedan/sedan-back (890).jpg
#   inflating: test/sedan/sedan-back (891).jpg
#   inflating: test/sedan/sedan-back (899).jpg
#   inflating: test/sedan/sedan-back (900).jpg
#   inflating: test/sedan/sedan-back (924).jpg
#   inflating: test/sedan/sedan-back (925).jpg
#   inflating: test/sedan/sedan-back (926).jpg
#   inflating: test/sedan/sedan-back (927).jpg
#   inflating: test/sedan/sedan-back (948).jpg
#   inflating: test/sedan/sedan-back (949).jpg
#   inflating: test/sedan/sedan-back (95).jpg
#   inflating: test/sedan/sedan-back (950).jpg
#   inflating: test/sedan/sedan-back (951).jpg
#   inflating: test/sedan/sedan-back (959).jpg
#   inflating: test/sedan/sedan-back (983).jpg
#   inflating: test/sedan/sedan-back (984).jpg
#   inflating: test/sedan/sedan-back (985).jpg
#   inflating: test/sedan/sedan-back (986).jpg
#    creating: test/truck/
#   inflating: test/truck/truck-back (104).jpg
#   inflating: test/truck/truck-back (105).jpg
#   inflating: test/truck/truck-back (106).jpg
#   inflating: test/truck/truck-back (107).jpg
#   inflating: test/truck/truck-back (108).jpg
#   inflating: test/truck/truck-back (116).jpg
#   inflating: test/truck/truck-back (117).jpg
#   inflating: test/truck/truck-back (118).jpg
#   inflating: test/truck/truck-back (119).jpg
#   inflating: test/truck/truck-back (120).jpg
#   inflating: test/truck/truck-back (128).jpg
#   inflating: test/truck/truck-back (129).jpg
#   inflating: test/truck/truck-back (20).jpg
#   inflating: test/truck/truck-back (21).jpg
#   inflating: test/truck/truck-back (22).jpg
#   inflating: test/truck/truck-back (23).jpg
#   inflating: test/truck/truck-back (24).jpg
#   inflating: test/truck/truck-back (32).jpg
#   inflating: test/truck/truck-back (33).jpg
#   inflating: test/truck/truck-back (34).jpg
#   inflating: test/truck/truck-back (35).jpg
#   inflating: test/truck/truck-back (36).jpg
#   inflating: test/truck/truck-back (44).jpg
#   inflating: test/truck/truck-back (45).jpg
#   inflating: test/truck/truck-back (46).jpg
#   inflating: test/truck/truck-back (47).jpg
#   inflating: test/truck/truck-back (48).jpg
#   inflating: test/truck/truck-back (56).jpg
#   inflating: test/truck/truck-back (57).jpg
#   inflating: test/truck/truck-back (58).jpg
#   inflating: test/truck/truck-back (59).jpg
#   inflating: test/truck/truck-back (60).jpg
#   inflating: test/truck/truck-back (68).jpg
#   inflating: test/truck/truck-back (69).jpg
#   inflating: test/truck/truck-back (70).jpg
#   inflating: test/truck/truck-back (71).jpg
#   inflating: test/truck/truck-back (72).jpg
#   inflating: test/truck/truck-back (80).jpg
#   inflating: test/truck/truck-back (81).jpg
#   inflating: test/truck/truck-back (82).jpg
#   inflating: test/truck/truck-back (83).jpg
#   inflating: test/truck/truck-back (84).jpg
#   inflating: test/truck/truck-back (92).jpg
#   inflating: test/truck/truck-back (93).jpg
#   inflating: test/truck/truck-back (94).jpg
#   inflating: test/truck/truck-back (95).jpg
#   inflating: test/truck/truck-back (96).jpg
#   inflating: test/truck/truck-front (1).jpg
#   inflating: test/truck/truck-front (11).jpg
#   inflating: test/truck/truck-front (12).jpg
#   inflating: test/truck/truck-front (13).jpg
#   inflating: test/truck/truck-front (14).jpg
#   inflating: test/truck/truck-front (15).jpg
#   inflating: test/truck/truck-front (2).jpg
#   inflating: test/truck/truck-front (23).jpg
#   inflating: test/truck/truck-front (24).jpg
#   inflating: test/truck/truck-front (25).jpg
#   inflating: test/truck/truck-front (26).jpg
#   inflating: test/truck/truck-front (27).jpg
#   inflating: test/truck/truck-front (3).jpg
#   inflating: test/truck/truck-front (35).jpg
#   inflating: test/truck/truck-front (36).jpg
#   inflating: test/truck/truck-front (37).jpg
#   inflating: test/truck/truck-front (38).jpg
#   inflating: test/truck/truck-front (39).jpg
#    creating: test/van/
#   inflating: test/van/van-back (100).jpg
#   inflating: test/van/van-back (101).jpg
#   inflating: test/van/van-back (102).jpg
#   inflating: test/van/van-back (103).jpg
#   inflating: test/van/van-back (104).jpg
#   inflating: test/van/van-back (112).jpg
#   inflating: test/van/van-back (113).jpg
#   inflating: test/van/van-back (114).jpg
#   inflating: test/van/van-back (115).jpg
#   inflating: test/van/van-back (116).jpg
#   inflating: test/van/van-back (124).jpg
#   inflating: test/van/van-back (125).jpg
#   inflating: test/van/van-back (126).jpg
#   inflating: test/van/van-back (127).jpg
#   inflating: test/van/van-back (128).jpg
#   inflating: test/van/van-back (136).jpg
#   inflating: test/van/van-back (137).jpg
#   inflating: test/van/van-back (138).jpg
#   inflating: test/van/van-back (139).jpg
#   inflating: test/van/van-back (140).jpg
#   inflating: test/van/van-back (148).jpg
#   inflating: test/van/van-back (149).jpg
#   inflating: test/van/van-back (150).jpg
#   inflating: test/van/van-back (151).jpg
#   inflating: test/van/van-back (152).jpg
#   inflating: test/van/van-back (160).jpg
#   inflating: test/van/van-back (161).jpg
#   inflating: test/van/van-back (162).jpg
#   inflating: test/van/van-back (163).jpg
#   inflating: test/van/van-back (164).jpg
#   inflating: test/van/van-back (172).jpg
#   inflating: test/van/van-back (173).jpg
#   inflating: test/van/van-back (174).jpg
#   inflating: test/van/van-back (175).jpg
#   inflating: test/van/van-back (176).jpg
#   inflating: test/van/van-back (184).jpg
#   inflating: test/van/van-back (185).jpg
#   inflating: test/van/van-back (186).jpg
#   inflating: test/van/van-back (187).jpg
#   inflating: test/van/van-back (188).jpg
#   inflating: test/van/van-back (196).jpg
#   inflating: test/van/van-back (197).jpg
#   inflating: test/van/van-back (198).jpg
#   inflating: test/van/van-back (199).jpg
#   inflating: test/van/van-back (200).jpg
#   inflating: test/van/van-back (208).jpg
#   inflating: test/van/van-back (209).jpg
#   inflating: test/van/van-back (210).jpg
#   inflating: test/van/van-back (211).jpg
#   inflating: test/van/van-back (212).jpg
#   inflating: test/van/van-back (40).jpg
#   inflating: test/van/van-back (41).jpg
#   inflating: test/van/van-back (42).jpg
#   inflating: test/van/van-back (43).jpg
#   inflating: test/van/van-back (44).jpg
#   inflating: test/van/van-back (52).jpg
#   inflating: test/van/van-back (53).jpg
#   inflating: test/van/van-back (54).jpg
#   inflating: test/van/van-back (55).jpg
#   inflating: test/van/van-back (56).jpg
#   inflating: test/van/van-back (64).jpg
#   inflating: test/van/van-back (65).jpg
#   inflating: test/van/van-back (66).jpg
#   inflating: test/van/van-back (67).jpg
#   inflating: test/van/van-back (68).jpg
#   inflating: test/van/van-back (76).jpg
#   inflating: test/van/van-back (77).jpg
#   inflating: test/van/van-back (78).jpg
#   inflating: test/van/van-back (79).jpg
#   inflating: test/van/van-back (80).jpg
#   inflating: test/van/van-back (88).jpg
#   inflating: test/van/van-back (89).jpg
#   inflating: test/van/van-back (90).jpg
#   inflating: test/van/van-back (91).jpg
#   inflating: test/van/van-back (92).jpg
#   inflating: test/van/van-front (10).jpg
#   inflating: test/van/van-front (11).jpg
#   inflating: test/van/van-front (19).jpg
#   inflating: test/van/van-front (20).jpg
#   inflating: test/van/van-front (21).jpg
#   inflating: test/van/van-front (22).jpg
#   inflating: test/van/van-front (23).jpg
#   inflating: test/van/van-front (31).jpg
#   inflating: test/van/van-front (32).jpg
#   inflating: test/van/van-front (33).jpg
#   inflating: test/van/van-front (34).jpg
#   inflating: test/van/van-front (35).jpg
#   inflating: test/van/van-front (43).jpg
#   inflating: test/van/van-front (44).jpg
#   inflating: test/van/van-front (45).jpg
#   inflating: test/van/van-front (46).jpg
#   inflating: test/van/van-front (47).jpg
#   inflating: test/van/van-front (55).jpg
#   inflating: test/van/van-front (56).jpg
#   inflating: test/van/van-front (57).jpg
#   inflating: test/van/van-front (58).jpg
#   inflating: test/van/van-front (59).jpg
#   inflating: test/van/van-front (67).jpg
#   inflating: test/van/van-front (68).jpg
#   inflating: test/van/van-front (69).jpg
#   inflating: test/van/van-front (7).jpg
#   inflating: test/van/van-front (70).jpg
#   inflating: test/van/van-front (71).jpg
#   inflating: test/van/van-front (8).jpg
#   inflating: test/van/van-front (9).jpg

# %%
import os
import time
import torch
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.optim import Adamax
from torchsummary import summary
from torchvision import datasets
from torchvision.models import vgg16, mobilenet_v3_small
from torchvision.models import resnet18
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
num_classes = 8
batch_size = 16
IMAGE_SIZE = (300, 300)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def images_transforms():
    data_transformation = transforms.Compose([
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])     
    
    return data_transformation

# %%
trainig_path = 'augmented_data'
test_path = 'test'
dataset = datasets.ImageFolder(trainig_path, transform=images_transforms())
targets = dataset.targets

train_idx, valid_idx= train_test_split(np.arange(len(targets)), test_size=0.2, shuffle=True, stratify=targets)
train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
valid_sampler = torch.utils.data.SubsetRandomSampler(valid_idx)

train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
val_loader = DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler)

test_dataset = datasets.ImageFolder(test_path, transform=images_transforms())
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# trainig_path = 'augmented_data'
# test_path = 'test'
# dataset = datasets.ImageFolder(trainig_path, transform=images_transforms())

# trainset, valset = random_split(dataset, [8715 , 966])
# train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
# val_loader = DataLoader(valset, batch_size=batch_size, shuffle=True, num_workers=2)

# test_dataset = datasets.ImageFolder(test_path, transform=images_transforms())
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
model = mobilenet_v3_small(weights='IMAGENET1K_V1')
for param in model.parameters():
    param.requires_grad = False
num_features = model.classifier[0].in_features
model.classifier = nn.Sequential(
    nn.Linear(in_features=num_features, out_features=64, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.4, inplace=False),
    nn.Linear(in_features=64, out_features=32, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.4, inplace=False),
    nn.Linear(in_features=32, out_features=num_classes, bias=True)
  )
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
#   0%|          | 0.00/9.83M [00:00<?, ?B/s]

# %%
model = model.to(device)

# %%
IMAGE_SIZE = (300, 300)
IMAGE_SIZE = (3,) + IMAGE_SIZE
print(summary(model, IMAGE_SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 150, 150]             432
#        BatchNorm2d-2         [-1, 16, 150, 150]              32
#          Hardswish-3         [-1, 16, 150, 150]               0
#             Conv2d-4           [-1, 16, 75, 75]             144
#        BatchNorm2d-5           [-1, 16, 75, 75]              32
#               ReLU-6           [-1, 16, 75, 75]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#       Hardsigmoid-11             [-1, 16, 1, 1]               0
# SqueezeExcitation-12           [-1, 16, 75, 75]               0
#            Conv2d-13           [-1, 16, 75, 75]             256
#       BatchNorm2d-14           [-1, 16, 75, 75]              32
#  InvertedResidual-15           [-1, 16, 75, 75]               0
#            Conv2d-16           [-1, 72, 75, 75]           1,152
#       BatchNorm2d-17           [-1, 72, 75, 75]             144
#              ReLU-18           [-1, 72, 75, 75]               0
#            Conv2d-19           [-1, 72, 38, 38]             648
#       BatchNorm2d-20           [-1, 72, 38, 38]             144
#              ReLU-21           [-1, 72, 38, 38]               0
#            Conv2d-22           [-1, 24, 38, 38]           1,728
#       BatchNorm2d-23           [-1, 24, 38, 38]              48
#  InvertedResidual-24           [-1, 24, 38, 38]               0
#            Conv2d-25           [-1, 88, 38, 38]           2,112
#       BatchNorm2d-26           [-1, 88, 38, 38]             176
#              ReLU-27           [-1, 88, 38, 38]               0
#            Conv2d-28           [-1, 88, 38, 38]             792
#       BatchNorm2d-29           [-1, 88, 38, 38]             176
#              ReLU-30           [-1, 88, 38, 38]               0
#            Conv2d-31           [-1, 24, 38, 38]           2,112
#       BatchNorm2d-32           [-1, 24, 38, 38]              48
#  InvertedResidual-33           [-1, 24, 38, 38]               0
#            Conv2d-34           [-1, 96, 38, 38]           2,304
#       BatchNorm2d-35           [-1, 96, 38, 38]             192
#         Hardswish-36           [-1, 96, 38, 38]               0
#            Conv2d-37           [-1, 96, 19, 19]           2,400
#       BatchNorm2d-38           [-1, 96, 19, 19]             192
#         Hardswish-39           [-1, 96, 19, 19]               0
# AdaptiveAvgPool2d-40             [-1, 96, 1, 1]               0
#            Conv2d-41             [-1, 24, 1, 1]           2,328
#              ReLU-42             [-1, 24, 1, 1]               0
#            Conv2d-43             [-1, 96, 1, 1]           2,400
#       Hardsigmoid-44             [-1, 96, 1, 1]               0
# SqueezeExcitation-45           [-1, 96, 19, 19]               0
#            Conv2d-46           [-1, 40, 19, 19]           3,840
#       BatchNorm2d-47           [-1, 40, 19, 19]              80
#  InvertedResidual-48           [-1, 40, 19, 19]               0
#            Conv2d-49          [-1, 240, 19, 19]           9,600
#       BatchNorm2d-50          [-1, 240, 19, 19]             480
#         Hardswish-51          [-1, 240, 19, 19]               0
#            Conv2d-52          [-1, 240, 19, 19]           6,000
#       BatchNorm2d-53          [-1, 240, 19, 19]             480
#         Hardswish-54          [-1, 240, 19, 19]               0
# AdaptiveAvgPool2d-55            [-1, 240, 1, 1]               0
#            Conv2d-56             [-1, 64, 1, 1]          15,424
#              ReLU-57             [-1, 64, 1, 1]               0
#            Conv2d-58            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-59            [-1, 240, 1, 1]               0
# SqueezeExcitation-
               0
# AdaptiveAvgPool2d-145            [-1, 576, 1, 1]               0
#           Conv2d-146            [-1, 144, 1, 1]          83,088
#             ReLU-147            [-1, 144, 1, 1]               0
#           Conv2d-148            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-149            [-1, 576, 1, 1]               0
# SqueezeExcitation-150          [-1, 576, 10, 10]               0
#           Conv2d-151           [-1, 96, 10, 10]          55,296
#      BatchNorm2d-152           [-1, 96, 10, 10]             192
# InvertedResidual-153           [-1, 96, 10, 10]               0
#           Conv2d-154          [-1, 576, 10, 10]          55,296
#      BatchNorm2d-155          [-1, 576, 10, 10]           1,152
#        Hardswish-156          [-1, 576, 10, 10]               0
# AdaptiveAvgPool2d-157            [-1, 576, 1, 1]               0
#           Linear-158                   [-1, 64]          36,928
#             ReLU-159                   [-1, 64]               0
#          Dropout-160                   [-1, 64]               0
#           Linear-161                   [-1, 32]           2,080
#             ReLU-162                   [-1, 32]               0
#          Dropout-163                   [-1, 32]               0
#           Linear-164                    [-1, 8]             264
# ================================================================
# Total params: 966,280
# Trainable params: 39,272
# Non-trainable params: 927,008
# ----------------------------------------------------------------
# Input size (MB): 1.03
# Forward/backward pass size (MB): 63.91
# Params size (MB): 3.69
# Estimated Total Size (MB): 68.63
# ----------------------------------------------------------------
# None

# %%
epochs = 100
n_steps = len(train_loader)
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = Adamax(model.parameters(),lr=learning_rate)

# %%
def test(model,testloader):
    with torch.no_grad():
        n_correct = 0
        n_samples = 0
        y_pred = []
        y_actual = []
        for _, (images,labels) in enumerate(testloader):
            images = images.to(device)
            labels = labels.to(device)
            
            outputs=model(images)
            
            y_actual += list(np.array(labels.detach().cpu()).flatten())
            _, predictes = torch.max(outputs,1)
            y_pred += list(np.array(predictes.detach().cpu()).flatten())
            n_samples += labels.shape[0]

            n_correct += (predictes==labels).sum().item()
            
        y_actual = np.array(y_actual).flatten()
        y_pred = np.array(y_pred).flatten()
        print(np.unique(y_pred))
        acc = classification_report(y_actual, y_pred, target_names=dataset.classes)
        print(f"{acc}")
        print("Confusion matric :\n")

        labels = dataset.classes
        cm = confusion_matrix(y_actual, y_pred)
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(111)
        cax = ax.matshow(cm)
        plt.title('Confusion matrix of the classifier')
        fig.colorbar(cax)
        ax.set_xticklabels([''] + labels)
        ax.set_yticklabels([''] + labels)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()
        print()

# %%
def train(model, train_loader, criterion, optimizer, val_loader, epochs=25):
    train_losses, val_losses, train_acc, val_accuracies, train_acc_epoch, val_acc_epoch, y_actual, y_pred = [], [], [], [], [], [], [], []
    wait = 0
    patience = 5
    best_acc = 0.0
    min_loss = np.Inf
    if not os.path.exists("models") : os.mkdir("models")

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs} : ")
        y_actual, y_pred = [], []
        train_loss, val_loss = 0, 0

        # Train the model
        model.train()
        for step, (images, labels) in enumerate(train_loader):
            start_time = time.time()
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # Loss and accuracy
            train_loss += loss.item()
            
            _, predictes = torch.max(outputs, dim=1)
            y_actual += list(labels.data.cpu().numpy().flatten()) 
            y_pred += list(predictes.detach().cpu().numpy().flatten())

            acc = accuracy_score(y_actual, y_pred)
            end_time = time.time()
            ETA = (end_time-start_time)*(n_steps-step)
            print('\rstep [%d/%d] : loss = %.4f, accuracy = %.4f, ETA = %d sec ' % (step, n_steps, train_loss/(step+1), acc, ETA), end='')
        train_acc.append(accuracy_score(y_actual, y_pred))
        print('\rstep [%d/%d] : loss = %.4f, accuracy = %.4f ' % (step+1, n_steps, train_loss/(step+1), acc), end='')


        # Evaluate the model
        model.eval()
        for i, (images, labels) in enumerate(val_loader):
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Loss and accuracy
            val_loss += loss.item()
            _,predictes=torch.max(outputs, 1)
            y_actual += list(labels.data.cpu().numpy().flatten()) 
            y_pred += list(predictes.detach().cpu().numpy().flatten())
        
        val_accuracies.append(accuracy_score(y_actual, y_pred))

        # Average losses and accuracies
        train_loss = train_loss/len(train_loader)
        val_loss = val_loss/len(val_loader)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        training_acc = train_acc[-1]
        val_acc = val_accuracies[-1]
        train_acc_epoch.append(training_acc)
        val_acc_epoch.append(val_acc)

        # Updating best validation accuracy
        if best_acc < val_acc:
            best_acc = val_acc

        print(", val_loss = %.4f, val_accuracy = %.4f" % (val_loss, val_acc))

        wait += 1
        # Saving best model
        if min_loss >= val_loss:
            torch.save(model.state_dict(), 'models/mob.pt')
            print("val_loss improved from %.4f to %.4f, model saved to models/mob.pt" % (min_loss, val_loss))
            min_loss = val_loss
            wait = 0

        else :
            print("val_loss did not improve, skip checkpoint")
        print('=' * 80)

        # Early stopping
        if wait >= patience:
            print(f"val_loss did not improved for series of {wait} epochs, Apply early stopping")
            break
        
    return train_losses, val_losses, train_acc, val_acc, train_acc_epoch, val_acc_epoch

# %%
train_losses, val_losses, train_acc, val_acc, train_acc_epoch, val_acc_epoch = train(model, train_loader, criterion, optimizer, val_loader, epochs)
# Out:
# Epoch 1/100 :
# step [484/484] : loss = 1.7858, accuracy = 0.3204 , val_loss = 1.3730, val_accuracy = 0.3697
# val_loss improved from inf to 1.3730, model saved to models/mob.pt
# ================================================================================
# Epoch 2/100 :
# step [484/484] : loss = 1.4099, accuracy = 0.4556 , val_loss = 1.0859, val_accuracy = 0.4868
# val_loss improved from 1.3730 to 1.0859, model saved to models/mob.pt
# ================================================================================
# Epoch 3/100 :
# step [484/484] : loss = 1.2320, accuracy = 0.5200 , val_loss = 0.9500, val_accuracy = 0.5477
# val_loss improved from 1.0859 to 0.9500, model saved to models/mob.pt
# ================================================================================
# Epoch 4/100 :
# step [484/484] : loss = 1.1239, accuracy = 0.5621 , val_loss = 0.8628, val_accuracy = 0.5842
# val_loss improved from 0.9500 to 0.8628, model saved to models/mob.pt
# ================================================================================
# Epoch 5/100 :
# step [484/484] : loss = 1.0550, accuracy = 0.5885 , val_loss = 0.8109, val_accuracy = 0.6119
# val_loss improved from 0.8628 to 0.8109, model saved to models/mob.pt
# ================================================================================
# Epoch 6/100 :
# step [484/484] : loss = 1.0162, accuracy = 0.6074 , val_loss = 0.7553, val_accuracy = 0.6335
# val_loss improved from 0.8109 to 0.7553, model saved to models/mob.pt
# ================================================================================
# Epoch 7/100 :
# step [484/484] : loss = 0.9630, accuracy = 0.6344 , val_loss = 0.7142, val_accuracy = 0.6594
# val_loss improved from 0.7553 to 0.7142, model saved to models/mob.pt
# ================================================================================
# Epoch 8/100 :
# step [484/484] : loss = 0.9168, accuracy = 0.6460 , val_loss = 0.6679, val_accuracy = 0.6704
# val_loss improved from 0.7142 to 0.6679, model saved to models/mob.pt
# ================================================================================
# Epoch 9/100 :
# step [484/484] : loss = 0.8955, accuracy = 0.6627 , val_loss = 0.6616, val_accuracy = 0.6832
# val_loss improved from 0.6679 to 0.6616, model saved to models/mob.pt
# ================================================================================
# Epoch 10/100 :
# step [484/484] : loss = 0.8566, accuracy = 0.6737 , val_loss = 0.6112, val_accuracy = 0.6958
# val_loss improved from 0.6616 to 0.6112, model saved to models/mob.pt
# ================================================================================
# Epoch 11/100 :
# step [484/484] : loss = 0.8379, accuracy = 0.6845 , val_loss = 0.6005, val_accuracy = 0.7049
# val_loss improved from 0.6112 to 0.6005, model saved to models/mob.pt
# ================================================================================
# Epoch 12/100 :
# step [484/484] : loss = 0.8149, accuracy = 0.7033 , val_loss = 0.5612, val_accuracy = 0.7222
# val_loss improved from 0.6005 to 0.5612, model saved to models/mob.pt
# ================================================================================
# Epoch 13/100 :
# step [484/484] : loss = 0.7785, accuracy = 0.7101 , val_loss = 0.5503, val_accuracy = 0.7298
# val_loss improved from 0.5612 to 0.5503, model saved to models/mob.pt
# ================================================================================
# Epoch 14/100 :
# step [484/484] : loss = 0.7593, accuracy = 0.7217 , val_loss = 0.5415, val_accuracy = 0.7399
# val_loss improved from 0.5503 to 0.5415, model saved to models/mob.pt
# ================================================================================
# Epoch 15/100 :
# step [484/484] : loss = 0.7388, accuracy = 0.7308 , val_loss = 0.5139, val_accuracy = 0.7480
# val_loss improved from 0.5415 to 0.5139, model saved to models/mob.pt
# ================================================================================
# Epoch 16/100 :
# step [484/484] : loss = 0.7283, accuracy = 0.7384 , val_loss = 0.5130, val_accuracy = 0.7544
# val_loss improved from 0.5139 to 0.5130, model saved to models/mob.pt
# ================================================================================
# Epoch 17/100 :
# step [484/484] : loss = 0.7218, accuracy = 0.7404 , val_loss = 0.4907, val_accuracy = 0.7584
# val_loss improved from 0.5130 to 0.4907, model saved to models/mob.pt
# ================================================================================
# Epoch 18/100 :
# step [484/484] : loss = 0.6923, accuracy = 0.7448 , val_loss = 0.4844, val_accuracy = 0.7650
# val_loss improved from 0.4907 to 0.4844, model saved to models/mob.pt
# ================================================================================
# Epoch 19/100 :
# step [484/484] : loss = 0.6670, accuracy = 0.7577 , val_loss = 0.4779, val_accuracy = 0.7735
# val_loss improved from 0.4844 to 0.4779, model saved to models/mob.pt
# ================================================================================
# Epoch 20/100 :
# step [484/484] : loss = 0.6698, accuracy = 0.7634 , val_loss = 0.4732, val_accuracy = 0.7786
# val_loss improved from 0.4779 to 0.4732, model saved to models/mob.pt
# ================================================================================
# Epoch 21/100 :
# step [484/484] : loss = 0.6477, accuracy = 0.7674 , val_loss = 0.4456, val_accuracy = 0.7832
# val_loss improved from 0.4732 to 0.4456, model saved to models/mob.pt
# ================================================================================
# Epoch 22/100 :
# step [484/484] : loss = 0.6428, accuracy = 0.7747 , val_loss = 0.4337, val_accuracy = 0.7893
# val_loss improved from 0.4456 to 0.4337, model saved to models/mob.pt
# ================================================================================
# Epoch 23/100 :
# step [484/484] : loss = 0.6216, accuracy = 0.7820 , val_loss = 0.4196, val_accuracy = 0.7962
# val_loss improved from 0.4337 to 0.4196, model saved to models/mob.pt
# ================================================================================
# Epoch 24/100 :
# step [484/484] : loss = 0.6142, accuracy = 0.7843 , val_loss = 0.4250, val_accuracy = 0.7991
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 25/100 :
# step [484/484] : loss = 0.6125, accuracy = 0.7809 , val_loss = 0.4138, val_accuracy = 0.7959
# val_loss improved from 0.4196 to 0.4138, model saved to models/mob.pt
# ================================================================================
# Epoch 26/100 :
# step [484/484] : loss = 0.6117, accuracy = 0.7849 , val_loss = 0.4126, val_accuracy = 0.7987
# val_loss improved from 0.4138 to 0.4126, model saved to models/mob.pt
# ================================================================================
# Epoch 27/100 :
# step [484/484] : loss = 0.5972, accuracy = 0.7904 , val_loss = 0.3965, val_accuracy = 0.8049
# val_loss improved from 0.4126 to 0.3965, model saved to models/mob.pt
# ================================================================================
# Epoch 28/100 :
# step [484/484] : loss = 0.5870, accuracy = 0.8018 , val_loss = 0.3946, val_accuracy = 0.8140
# val_loss improved from 0.3965 to 0.3946, model saved to models/mob.pt
# ================================================================================
# Epoch 29/100 :
# step [484/484] : loss = 0.5891, accuracy = 0.7939 , val_loss = 0.3883, val_accuracy = 0.8078
# val_loss improved from 0.3946 to 0.3883, model saved to models/mob.pt
# ================================================================================
# Epoch 30/100 :
# step [484/484] : loss = 0.5681, accuracy = 0.8029 , val_loss = 0.3774, val_accuracy = 0.8164
# val_loss improved from 0.3883 to 0.3774, model saved to models/mob.pt
# ================================================================================
# Epoch 31/100 :
# step [484/484] : loss = 0.5694, accuracy = 0.8020 , val_loss = 0.3825, val_accuracy = 0.8146
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 32/100 :
# step [484/484] : loss = 0.5590, accuracy = 0.8084 , val_loss = 0.3725, val_accuracy = 0.8198
# val_loss improved from 0.3774 to 0.3725, model saved to models/mob.pt
# ================================================================================
# Epoch 33/100 :
# step [484/484] : loss = 0.5538, accuracy = 0.8103 , val_loss = 0.3822, val_accuracy = 0.8217
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 34/100 :
# step [484/484] : loss = 0.5459, accuracy = 0.8060 , val_loss = 0.3610, val_accuracy = 0.8200
# val_loss improved from 0.3725 to 0.3610, model saved to models/mob.pt
# ================================================================================
# Epoch 35/100 :
# step [484/484] : loss = 0.5408, accuracy = 0.8146 , val_loss = 0.3614, val_accuracy = 0.8255
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 36/100 :
# step [484/484] : loss = 0.5405, accuracy = 0.8133 , val_loss = 0.3678, val_accuracy = 0.8248
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 37/100 :
# step [484/484] : loss = 0.5243, accuracy = 0.8147 , val_loss = 0.3546, val_accuracy = 0.8254
# val_loss improved from 0.3610 to 0.3546, model saved to models/mob.pt
# ================================================================================
# Epoch 38/100 :
# step [484/484] : loss = 0.5127, accuracy = 0.8244 , val_loss = 0.3814, val_accuracy = 0.8346
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 39/100 :
# step [484/484] : loss = 0.5225, accuracy = 0.8243 , val_loss = 0.3784, val_accuracy = 0.8341
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 40/100 :
# step [484/484] : loss = 0.5066, accuracy = 0.8270 , val_loss = 0.3472, val_accuracy = 0.8375
# val_loss improved from 0.3546 to 0.3472, model saved to models/mob.pt
# ================================================================================
# Epoch 41/100 :
# step [484/484] : loss = 0.4971, accuracy = 0.8321 , val_loss = 0.3424, val_accuracy = 0.8416
# val_loss improved from 0.3472 to 0.3424, model saved to models/mob.pt
# ================================================================================
# Epoch 42/100 :
# step [484/484] : loss = 0.5098, accuracy = 0.8206 , val_loss = 0.3361, val_accuracy = 0.8325
# val_loss improved from 0.3424 to 0.3361, model saved to models/mob.pt
# ================================================================================
# Epoch 43/100 :
# step [484/484] : loss = 0.5066, accuracy = 0.8293 , val_loss = 0.3471, val_accuracy = 0.8385
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 44/100 :
# step [484/484] : loss = 0.4756, accuracy = 0.8339 , val_loss = 0.3370, val_accuracy = 0.8441
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 45/100 :
# step [484/484] : loss = 0.4777, accuracy = 0.8395 , val_loss = 0.3336, val_accuracy = 0.8478
# val_loss improved from 0.3361 to 0.3336, model saved to models/mob.pt
# ================================================================================
# Epoch 46/100 :
# step [484/484] : loss = 0.4749, accuracy = 0.8418 , val_loss = 0.3364, val_accuracy = 0.8493
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 47/100 :
# step [484/484] : loss = 0.4674, accuracy = 0.8363 , val_loss = 0.3242, val_accuracy = 0.8454
# val_loss improved from 0.3336 to 0.3242, model saved to models/mob.pt
# ================================================================================
# Epoch 48/100 :
# step [484/484] : loss = 0.4796, accuracy = 0.8335 , val_loss = 0.3527, val_accuracy = 0.8428
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 49/100 :
# step [484/484] : loss = 0.4691, accuracy = 0.8378 , val_loss = 0.3415, val_accuracy = 0.8470
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 50/100 :
# step [484/484] : loss = 0.4677, accuracy = 0.8409 , val_loss = 0.3158, val_accuracy = 0.8505
# val_loss improved from 0.3242 to 0.3158, model saved to models/mob.pt
# ================================================================================
# Epoch 51/100 :
# step [484/484] : loss = 0.4592, accuracy = 0.8441 , val_loss = 0.3252, val_accuracy = 0.8518
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 52/100 :
# step [484/484] : loss = 0.4631, accuracy = 0.8465 , val_loss = 0.3125, val_accuracy = 0.8549
# val_loss improved from 0.3158 to 0.3125, model saved to models/mob.pt
# ================================================================================
# Epoch 53/100 :
# step [484/484] : loss = 0.4534, accuracy = 0.8487 , val_loss = 0.3178, val_accuracy = 0.8571
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 54/100 :
# step [484/484] : loss = 0.4506, accuracy = 0.8450 , val_loss = 0.3196, val_accuracy = 0.8525
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 55/100 :
# step [484/484] : loss = 0.4550, accuracy = 0.8438 , val_loss = 0.3211, val_accuracy = 0.8513
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 56/100 :
# step [484/484] : loss = 0.4345, accuracy = 0.8512 , val_loss = 0.3095, val_accuracy = 0.8577
# val_loss improved from 0.3125 to 0.3095, model saved to models/mob.pt
# ================================================================================
# Epoch 57/100 :
# step [484/484] : loss = 0.4498, accuracy = 0.8466 , val_loss = 0.3093, val_accuracy = 0.8546
# val_loss improved from 0.3095 to 0.3093, model saved to models/mob.pt
# ================================================================================
# Epoch 58/100 :
# step [484/484] : loss = 0.4432, accuracy = 0.8506 , val_loss = 0.3054, val_accuracy = 0.8590
# val_loss improved from 0.3093 to 0.3054, model saved to models/mob.pt
# ================================================================================
# Epoch 59/100 :
# step [484/484] : loss = 0.4248, accuracy = 0.8547 , val_loss = 0.3145, val_accuracy = 0.8606
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 60/100 :
# step [484/484] : loss = 0.4345, accuracy = 0.8520 , val_loss = 0.3109, val_accuracy = 0.8598
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 61/100 :
# step [484/484] : loss = 0.4253, accuracy = 0.8554 , val_loss = 0.2999, val_accuracy = 0.8637
# val_loss improved from 0.3054 to 0.2999, model saved to models/mob.pt
# ================================================================================
# Epoch 62/100 :
# step [484/484] : loss = 0.4382, accuracy = 0.8518 , val_loss = 0.3026, val_accuracy = 0.8591
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 63/100 :
# step [484/484] : loss = 0.4208, accuracy = 0.8529 , val_loss = 0.3056, val_accuracy = 0.8607
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 64/100 :
# step [484/484] : loss = 0.4266, accuracy = 0.8545 , val_loss = 0.3105, val_accuracy = 0.8617
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 65/100 :
# step [484/484] : loss = 0.4229, accuracy = 0.8530 , val_loss = 0.2936, val_accuracy = 0.8610
# val_loss improved from 0.2999 to 0.2936, model saved to models/mob.pt
# ================================================================================
# Epoch 66/100 :
# step [484/484] : loss = 0.4069, accuracy = 0.8667 , val_loss = 0.2903, val_accuracy = 0.8718
# val_loss improved from 0.2936 to 0.2903, model saved to models/mob.pt
# ================================================================================
# Epoch 67/100 :
# step [484/484] : loss = 0.4032, accuracy = 0.8638 , val_loss = 0.2937, val_accuracy = 0.8690
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 68/100 :
# step [484/484] : loss = 0.4042, accuracy = 0.8651 , val_loss = 0.2992, val_accuracy = 0.8700
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 69/100 :
# step [484/484] : loss = 0.4114, accuracy = 0.8571 , val_loss = 0.2979, val_accuracy = 0.8632
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 70/100 :
# step [484/484] : loss = 0.4050, accuracy = 0.8590 , val_loss = 0.2928, val_accuracy = 0.8647
# val_loss did not improve, skip checkpoint
# ================================================================================
# Epoch 71/100 :
# step [484/484] : loss = 0.4006, accuracy = 0.8640 , val_loss = 0.2914, val_accuracy = 0.8703
# val_loss did not improve, skip checkpoint
# ================================================================================
# val_loss did not improved for series of 5 epochs, Apply early stopping

# %%
# !cp 'models/mob.pt' '/content/drive/MyDrive/aiactive/mob.pt'

# %%
plt.figure(figsize=(20,5))
plt.plot(train_losses, '-o', label="train")
plt.plot(val_losses, '-o', label="val")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss change over epoch")
plt.legend()

# %%
plt.figure(figsize=(20,5))
plt.plot(train_acc_epoch, '-o', label="train")
plt.plot(val_acc_epoch, '-o', label="val")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy over epoch")
plt.legend()

# %%
torch.save(model,'/content/drive/MyDrive/aiactive/saved_mob_model.h5')

# %%
import seaborn as sns

model.load_state_dict(torch.load('models/mob.pt'))
test(model, test_loader)
# Out:
# [0 1 2 3 4 5 6 7]
#               precision    recall  f1-score   support
#
#          bus       0.78      0.90      0.84        20
#    crossover       0.85      0.73      0.79       120
#    hatchback       0.55      0.68      0.61       105
#   motorcycle       1.00      1.00      1.00        22
# pickup-truck       0.88      0.90      0.89        90
#        sedan       0.91      0.90      0.90       396
#        truck       0.92      0.89      0.91        65
#          van       0.91      0.86      0.88       105
#
#     accuracy                           0.85       923
#    macro avg       0.85      0.86      0.85       923
# weighted avg       0.86      0.85      0.85       923
#
# Confusion matric :
